-- %% [markdown]
-- # [DW-Studenti]

-- %%
USE [master]
GO

-- %%
/****** Object:  Database [DW-Studenti]    Script Date: 01-Dec-25 1:16:03 PM ******/
CREATE DATABASE [DW-Studenti]
 CONTAINMENT = NONE
 ON  PRIMARY 
( NAME = N'DW-Studenti', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL15.SQLEXPRESS\MSSQL\DATA\DW-Studenti.mdf' , SIZE = 139264KB , MAXSIZE = UNLIMITED, FILEGROWTH = 65536KB )
 LOG ON 
( NAME = N'DW-Studenti_log', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL15.SQLEXPRESS\MSSQL\DATA\DW-Studenti_log.ldf' , SIZE = 73728KB , MAXSIZE = 2048GB , FILEGROWTH = 65536KB )
 WITH CATALOG_COLLATION = DATABASE_DEFAULT
GO
ALTER DATABASE [DW-Studenti] SET COMPATIBILITY_LEVEL = 150
GO
IF (1 = FULLTEXTSERVICEPROPERTY('IsFullTextInstalled'))
begin
EXEC [DW-Studenti].[dbo].[sp_fulltext_database] @action = 'enable'
end
GO
ALTER DATABASE [DW-Studenti] SET ANSI_NULL_DEFAULT OFF 
GO
ALTER DATABASE [DW-Studenti] SET ANSI_NULLS OFF 
GO
ALTER DATABASE [DW-Studenti] SET ANSI_PADDING OFF 
GO
ALTER DATABASE [DW-Studenti] SET ANSI_WARNINGS OFF 
GO
ALTER DATABASE [DW-Studenti] SET ARITHABORT OFF 
GO
ALTER DATABASE [DW-Studenti] SET AUTO_CLOSE OFF 
GO
ALTER DATABASE [DW-Studenti] SET AUTO_SHRINK OFF 
GO
ALTER DATABASE [DW-Studenti] SET AUTO_UPDATE_STATISTICS ON 
GO
ALTER DATABASE [DW-Studenti] SET CURSOR_CLOSE_ON_COMMIT OFF 
GO
ALTER DATABASE [DW-Studenti] SET CURSOR_DEFAULT  GLOBAL 
GO
ALTER DATABASE [DW-Studenti] SET CONCAT_NULL_YIELDS_NULL OFF 
GO
ALTER DATABASE [DW-Studenti] SET NUMERIC_ROUNDABORT OFF 
GO
ALTER DATABASE [DW-Studenti] SET QUOTED_IDENTIFIER OFF 
GO
ALTER DATABASE [DW-Studenti] SET RECURSIVE_TRIGGERS OFF 
GO
ALTER DATABASE [DW-Studenti] SET  DISABLE_BROKER 
GO
ALTER DATABASE [DW-Studenti] SET AUTO_UPDATE_STATISTICS_ASYNC OFF 
GO
ALTER DATABASE [DW-Studenti] SET DATE_CORRELATION_OPTIMIZATION OFF 
GO
ALTER DATABASE [DW-Studenti] SET TRUSTWORTHY OFF 
GO
ALTER DATABASE [DW-Studenti] SET ALLOW_SNAPSHOT_ISOLATION OFF 
GO
ALTER DATABASE [DW-Studenti] SET PARAMETERIZATION SIMPLE 
GO
ALTER DATABASE [DW-Studenti] SET READ_COMMITTED_SNAPSHOT OFF 
GO
ALTER DATABASE [DW-Studenti] SET HONOR_BROKER_PRIORITY OFF 
GO
ALTER DATABASE [DW-Studenti] SET RECOVERY SIMPLE 
GO
ALTER DATABASE [DW-Studenti] SET  MULTI_USER 
GO
ALTER DATABASE [DW-Studenti] SET PAGE_VERIFY CHECKSUM  
GO
ALTER DATABASE [DW-Studenti] SET DB_CHAINING OFF 
GO
ALTER DATABASE [DW-Studenti] SET FILESTREAM( NON_TRANSACTED_ACCESS = OFF ) 
GO
ALTER DATABASE [DW-Studenti] SET TARGET_RECOVERY_TIME = 60 SECONDS 
GO
ALTER DATABASE [DW-Studenti] SET DELAYED_DURABILITY = DISABLED 
GO
ALTER DATABASE [DW-Studenti] SET ACCELERATED_DATABASE_RECOVERY = OFF  
GO
ALTER DATABASE [DW-Studenti] SET QUERY_STORE = OFF
GO

-- %% [markdown]
-- # [dbo].[Dim_Predmet]

-- %%
USE [DW-Studenti]
GO

-- %%
/****** Object:  Table [dbo].[Dim_Predmet]    Script Date: 01-Dec-25 1:16:03 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Dim_Predmet](
	[predmet_SID] [int] IDENTITY(1,1) NOT NULL,
	[id_predmet] [int] NOT NULL,
	[ima_lab] [bit] NULL,
	[predmet_naziv] [nvarchar](100) NULL,
 CONSTRAINT [PK_Dim_Predmet] PRIMARY KEY CLUSTERED 
(
	[predmet_SID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Dim_Prijava]

-- %%
/****** Object:  Table [dbo].[Dim_Prijava]    Script Date: 01-Dec-25 1:16:03 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Dim_Prijava](
	[prijava_SID] [int] IDENTITY(1,1) NOT NULL,
	[ocena] [nvarchar](50) NULL,
	[fk_rok] [int] NOT NULL,
	[fk_predmet] [int] NOT NULL,
	[fk_student] [int] NOT NULL,
	[f_polozen] [bit] NULL,
 CONSTRAINT [PK_Dim_Prijava] PRIMARY KEY CLUSTERED 
(
	[prijava_SID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Dim_Student]

-- %%
/****** Object:  Table [dbo].[Dim_Student]    Script Date: 01-Dec-25 1:16:03 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Dim_Student](
	[student_SID] [int] IDENTITY(1,1) NOT NULL,
	[id_student] [int] NOT NULL,
	[drzava_rodjenja] [nvarchar](100) NULL,
	[naziv_srednje_skole] [nvarchar](200) NULL,
 CONSTRAINT [PK_Dim_Student] PRIMARY KEY CLUSTERED 
(
	[student_SID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Dim_Vreme]

-- %%
/****** Object:  Table [dbo].[Dim_Vreme]    Script Date: 01-Dec-25 1:16:03 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Dim_Vreme](
	[vreme_SID] [int] IDENTITY(1,1) NOT NULL,
	[id_rok] [int] NOT NULL,
	[naziv_roka] [nvarchar](50) NULL,
	[skolska_godina] [smallint] NULL,
 CONSTRAINT [PK_Dim_Vreme] PRIMARY KEY CLUSTERED 
(
	[vreme_SID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Fact_efikasnost_nastave]

-- %%
/****** Object:  Table [dbo].[Fact_efikasnost_nastave]    Script Date: 01-Dec-25 1:16:03 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Fact_efikasnost_nastave](
	[efikasnost_nastave_SID] [int] IDENTITY(1,1) NOT NULL,
	[vreme_SID] [int] NOT NULL,
	[predmet_SID] [int] NOT NULL,
	[prijava_SID] [int] NOT NULL,
	[prolaznost_po_predmetu] [float] NULL,
	[prosecna_ocena_po_predmetu] [float] NULL,
	[prosecna_ocena_sa_lab] [float] NULL,
	[prosecna_ocena_bez_lab] [float] NULL,
 CONSTRAINT [PK_Fact_efikasnost_nastave] PRIMARY KEY CLUSTERED 
(
	[efikasnost_nastave_SID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Fact_Uspesnost]

-- %%
/****** Object:  Table [dbo].[Fact_Uspesnost]    Script Date: 01-Dec-25 1:16:03 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Fact_Uspesnost](
	[uspesnost_SID] [int] IDENTITY(1,1) NOT NULL,
	[vreme_SID] [int] NOT NULL,
	[student_SID] [int] NOT NULL,
	[prijava_SID] [int] NOT NULL,
	[predmet_SID] [int] NOT NULL,
	[prosecna_ocena_studenta] [float] NULL,
	[redni_broj_prijave_polozenog_ispita] [int] NULL,
	[prosecna_ocena_po_drzavi] [float] NULL,
	[prosecna_ocena_po_skoli] [float] NULL,
	[krajnja_ocena_na_predmetu] [int] NULL,
 CONSTRAINT [PK_Fact_Uspesnost] PRIMARY KEY CLUSTERED 
(
	[uspesnost_SID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [FK_Dim_Prijava_Dim_Predmet]

-- %%
ALTER TABLE [dbo].[Dim_Prijava]  WITH CHECK ADD  CONSTRAINT [FK_Dim_Prijava_Dim_Predmet] FOREIGN KEY([fk_predmet])
REFERENCES [dbo].[Dim_Predmet] ([predmet_SID])
GO
ALTER TABLE [dbo].[Dim_Prijava] CHECK CONSTRAINT [FK_Dim_Prijava_Dim_Predmet]
GO

-- %% [markdown]
-- # [FK_Dim_Prijava_Dim_Student]

-- %%
ALTER TABLE [dbo].[Dim_Prijava]  WITH CHECK ADD  CONSTRAINT [FK_Dim_Prijava_Dim_Student] FOREIGN KEY([fk_student])
REFERENCES [dbo].[Dim_Student] ([student_SID])
GO
ALTER TABLE [dbo].[Dim_Prijava] CHECK CONSTRAINT [FK_Dim_Prijava_Dim_Student]
GO

-- %% [markdown]
-- # [FK_Dim_Prijava_Dim_Vreme]

-- %%
ALTER TABLE [dbo].[Dim_Prijava]  WITH CHECK ADD  CONSTRAINT [FK_Dim_Prijava_Dim_Vreme] FOREIGN KEY([fk_rok])
REFERENCES [dbo].[Dim_Vreme] ([vreme_SID])
GO
ALTER TABLE [dbo].[Dim_Prijava] CHECK CONSTRAINT [FK_Dim_Prijava_Dim_Vreme]
GO

-- %% [markdown]
-- # [FK_Fact_efikasnost_nastave_Dim_Predmet]

-- %%
ALTER TABLE [dbo].[Fact_efikasnost_nastave]  WITH CHECK ADD  CONSTRAINT [FK_Fact_efikasnost_nastave_Dim_Predmet] FOREIGN KEY([predmet_SID])
REFERENCES [dbo].[Dim_Predmet] ([predmet_SID])
GO
ALTER TABLE [dbo].[Fact_efikasnost_nastave] CHECK CONSTRAINT [FK_Fact_efikasnost_nastave_Dim_Predmet]
GO

-- %% [markdown]
-- # [FK_Fact_efikasnost_nastave_Dim_Prijava]

-- %%
ALTER TABLE [dbo].[Fact_efikasnost_nastave]  WITH CHECK ADD  CONSTRAINT [FK_Fact_efikasnost_nastave_Dim_Prijava] FOREIGN KEY([prijava_SID])
REFERENCES [dbo].[Dim_Prijava] ([prijava_SID])
GO
ALTER TABLE [dbo].[Fact_efikasnost_nastave] CHECK CONSTRAINT [FK_Fact_efikasnost_nastave_Dim_Prijava]
GO

-- %% [markdown]
-- # [FK_Fact_efikasnost_nastave_Dim_Vreme]

-- %%
ALTER TABLE [dbo].[Fact_efikasnost_nastave]  WITH CHECK ADD  CONSTRAINT [FK_Fact_efikasnost_nastave_Dim_Vreme] FOREIGN KEY([vreme_SID])
REFERENCES [dbo].[Dim_Vreme] ([vreme_SID])
GO
ALTER TABLE [dbo].[Fact_efikasnost_nastave] CHECK CONSTRAINT [FK_Fact_efikasnost_nastave_Dim_Vreme]
GO

-- %% [markdown]
-- # [FK_Fact_Uspesnost_Dim_Predmet]

-- %%
ALTER TABLE [dbo].[Fact_Uspesnost]  WITH CHECK ADD  CONSTRAINT [FK_Fact_Uspesnost_Dim_Predmet] FOREIGN KEY([predmet_SID])
REFERENCES [dbo].[Dim_Predmet] ([predmet_SID])
GO
ALTER TABLE [dbo].[Fact_Uspesnost] CHECK CONSTRAINT [FK_Fact_Uspesnost_Dim_Predmet]
GO

-- %% [markdown]
-- # [FK_Fact_Uspesnost_Dim_Prijava]

-- %%
ALTER TABLE [dbo].[Fact_Uspesnost]  WITH CHECK ADD  CONSTRAINT [FK_Fact_Uspesnost_Dim_Prijava] FOREIGN KEY([prijava_SID])
REFERENCES [dbo].[Dim_Prijava] ([prijava_SID])
GO
ALTER TABLE [dbo].[Fact_Uspesnost] CHECK CONSTRAINT [FK_Fact_Uspesnost_Dim_Prijava]
GO

-- %% [markdown]
-- # [FK_Fact_Uspesnost_Dim_Student]

-- %%
ALTER TABLE [dbo].[Fact_Uspesnost]  WITH CHECK ADD  CONSTRAINT [FK_Fact_Uspesnost_Dim_Student] FOREIGN KEY([student_SID])
REFERENCES [dbo].[Dim_Student] ([student_SID])
GO
ALTER TABLE [dbo].[Fact_Uspesnost] CHECK CONSTRAINT [FK_Fact_Uspesnost_Dim_Student]
GO

-- %% [markdown]
-- # [FK_Fact_Uspesnost_Dim_Vreme]

-- %%
ALTER TABLE [dbo].[Fact_Uspesnost]  WITH CHECK ADD  CONSTRAINT [FK_Fact_Uspesnost_Dim_Vreme] FOREIGN KEY([vreme_SID])
REFERENCES [dbo].[Dim_Vreme] ([vreme_SID])
GO
ALTER TABLE [dbo].[Fact_Uspesnost] CHECK CONSTRAINT [FK_Fact_Uspesnost_Dim_Vreme]
GO

-- %% [markdown]
-- # [DW-Studenti]

-- %%
USE [master]
GO

-- %%
ALTER DATABASE [DW-Studenti] SET  READ_WRITE 
GO
