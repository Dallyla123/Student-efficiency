-- %% [markdown]
-- # [Studenti]

-- %%
USE [master]
GO

-- %%
/****** Object:  Database [Studenti]    Script Date: 01-Dec-25 1:16:31 PM ******/
CREATE DATABASE [Studenti]
 CONTAINMENT = NONE
 ON  PRIMARY 
( NAME = N'Studenti', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL15.SQLEXPRESS\MSSQL\DATA\Studenti.mdf' , SIZE = 70656KB , MAXSIZE = UNLIMITED, FILEGROWTH = 1024KB )
 LOG ON 
( NAME = N'Studenti_log', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL15.SQLEXPRESS\MSSQL\DATA\Studenti_log.ldf' , SIZE = 3840KB , MAXSIZE = 2048GB , FILEGROWTH = 10%)
 WITH CATALOG_COLLATION = DATABASE_DEFAULT
GO
ALTER DATABASE [Studenti] SET COMPATIBILITY_LEVEL = 100
GO
IF (1 = FULLTEXTSERVICEPROPERTY('IsFullTextInstalled'))
begin
EXEC [Studenti].[dbo].[sp_fulltext_database] @action = 'enable'
end
GO
ALTER DATABASE [Studenti] SET ANSI_NULL_DEFAULT OFF 
GO
ALTER DATABASE [Studenti] SET ANSI_NULLS OFF 
GO
ALTER DATABASE [Studenti] SET ANSI_PADDING OFF 
GO
ALTER DATABASE [Studenti] SET ANSI_WARNINGS OFF 
GO
ALTER DATABASE [Studenti] SET ARITHABORT OFF 
GO
ALTER DATABASE [Studenti] SET AUTO_CLOSE ON 
GO
ALTER DATABASE [Studenti] SET AUTO_SHRINK OFF 
GO
ALTER DATABASE [Studenti] SET AUTO_UPDATE_STATISTICS ON 
GO
ALTER DATABASE [Studenti] SET CURSOR_CLOSE_ON_COMMIT OFF 
GO
ALTER DATABASE [Studenti] SET CURSOR_DEFAULT  GLOBAL 
GO
ALTER DATABASE [Studenti] SET CONCAT_NULL_YIELDS_NULL OFF 
GO
ALTER DATABASE [Studenti] SET NUMERIC_ROUNDABORT OFF 
GO
ALTER DATABASE [Studenti] SET QUOTED_IDENTIFIER OFF 
GO
ALTER DATABASE [Studenti] SET RECURSIVE_TRIGGERS OFF 
GO
ALTER DATABASE [Studenti] SET  DISABLE_BROKER 
GO
ALTER DATABASE [Studenti] SET AUTO_UPDATE_STATISTICS_ASYNC OFF 
GO
ALTER DATABASE [Studenti] SET DATE_CORRELATION_OPTIMIZATION OFF 
GO
ALTER DATABASE [Studenti] SET TRUSTWORTHY OFF 
GO
ALTER DATABASE [Studenti] SET ALLOW_SNAPSHOT_ISOLATION OFF 
GO
ALTER DATABASE [Studenti] SET PARAMETERIZATION SIMPLE 
GO
ALTER DATABASE [Studenti] SET READ_COMMITTED_SNAPSHOT OFF 
GO
ALTER DATABASE [Studenti] SET HONOR_BROKER_PRIORITY OFF 
GO
ALTER DATABASE [Studenti] SET RECOVERY SIMPLE 
GO
ALTER DATABASE [Studenti] SET  MULTI_USER 
GO
ALTER DATABASE [Studenti] SET PAGE_VERIFY CHECKSUM  
GO
ALTER DATABASE [Studenti] SET DB_CHAINING OFF 
GO
ALTER DATABASE [Studenti] SET FILESTREAM( NON_TRANSACTED_ACCESS = OFF ) 
GO
ALTER DATABASE [Studenti] SET TARGET_RECOVERY_TIME = 0 SECONDS 
GO
ALTER DATABASE [Studenti] SET DELAYED_DURABILITY = DISABLED 
GO
ALTER DATABASE [Studenti] SET ACCELERATED_DATABASE_RECOVERY = OFF  
GO
ALTER DATABASE [Studenti] SET QUERY_STORE = OFF
GO

-- %% [markdown]
-- # [dbo].[angazovanje]

-- %%
USE [Studenti]
GO

-- %%
/****** Object:  Table [dbo].[angazovanje]    Script Date: 01-Dec-25 1:16:31 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[angazovanje](
	[id_nastavnik] [smallint] NOT NULL,
	[id_predmet] [smallint] NOT NULL,
	[id_tip_nastave] [smallint] NOT NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Dim_Student]

-- %%
/****** Object:  Table [dbo].[Dim_Student]    Script Date: 01-Dec-25 1:16:31 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Dim_Student](
	[student_SID] [int] NOT NULL,
	[id_student] [smallint] NOT NULL,
	[drzava_rodjenja] [nvarchar](100) NULL,
	[naziv_srednje_skole] [nvarchar](200) NULL,
 CONSTRAINT [PK_Dim_Student] PRIMARY KEY CLUSTERED 
(
	[student_SID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[moguca_prijava]

-- %%
/****** Object:  Table [dbo].[moguca_prijava]    Script Date: 01-Dec-25 1:16:31 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[moguca_prijava](
	[id_student] [smallint] NOT NULL,
	[id_predmet] [smallint] NOT NULL,
	[id_tip_prijave] [smallint] NULL,
 CONSTRAINT [PK_moguca_prijava] PRIMARY KEY CLUSTERED 
(
	[id_student] ASC,
	[id_predmet] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[nastavnik]

-- %%
/****** Object:  Table [dbo].[nastavnik]    Script Date: 01-Dec-25 1:16:31 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[nastavnik](
	[id_nastavnik] [smallint] NOT NULL,
	[nastavnik_ime] [nvarchar](10) NULL,
	[nastavnik_prezime] [nvarchar](23) NULL,
 CONSTRAINT [PK_nastavnik] PRIMARY KEY CLUSTERED 
(
	[id_nastavnik] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[pracenje_predmeta]

-- %%
/****** Object:  Table [dbo].[pracenje_predmeta]    Script Date: 01-Dec-25 1:16:31 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[pracenje_predmeta](
	[id_student] [smallint] NULL,
	[id_predmet] [smallint] NULL,
	[id_tip_prijave] [smallint] NULL,
	[id_skolska_godina] [smallint] NULL,
	[id_semestar] [smallint] NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[predmet]

-- %%
/****** Object:  Table [dbo].[predmet]    Script Date: 01-Dec-25 1:16:31 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[predmet](
	[id_predmet] [smallint] NOT NULL,
	[predmet_akronim] [nvarchar](15) NULL,
	[predmet_naziv] [nvarchar](100) NULL,
	[aktivan] [nvarchar](2) NULL,
	[espb] [smallint] NULL,
 CONSTRAINT [PK_predmet] PRIMARY KEY CLUSTERED 
(
	[id_predmet] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[predmeti_po_planovima]

-- %%
/****** Object:  Table [dbo].[predmeti_po_planovima]    Script Date: 01-Dec-25 1:16:31 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[predmeti_po_planovima](
	[id_profil] [smallint] NULL,
	[id_semestar] [smallint] NULL,
	[id_predmet] [smallint] NULL,
	[f_obavezan] [bit] NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[profil]

-- %%
/****** Object:  Table [dbo].[profil]    Script Date: 01-Dec-25 1:16:31 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[profil](
	[id_profil] [smallint] NOT NULL,
	[akronim] [nvarchar](50) NULL,
	[naziv] [nvarchar](100) NULL,
 CONSTRAINT [PK_profil] PRIMARY KEY CLUSTERED 
(
	[id_profil] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[rezultat_ispita]

-- %%
/****** Object:  Table [dbo].[rezultat_ispita]    Script Date: 01-Dec-25 1:16:31 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[rezultat_ispita](
	[id_student] [smallint] NOT NULL,
	[id_predmet] [smallint] NOT NULL,
	[ocena] [nvarchar](50) NULL,
	[espb] [smallint] NULL,
	[bodovi] [smallint] NULL,
	[datum_polaganja] [varchar](50) NULL,
	[id_rok] [int] NULL,
	[id_nastavnik] [smallint] NULL,
	[id_tip_rezultata_ispita] [smallint] NULL,
	[f_polozen] [bit] NULL,
	[id_tip_prijave] [smallint] NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[sif_drzava]

-- %%
/****** Object:  Table [dbo].[sif_drzava]    Script Date: 01-Dec-25 1:16:31 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[sif_drzava](
	[id_drzava] [int] NOT NULL,
	[naziv] [nvarchar](100) NULL,
 CONSTRAINT [PK_sif_drzava] PRIMARY KEY CLUSTERED 
(
	[id_drzava] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[sif_godina_studija]

-- %%
/****** Object:  Table [dbo].[sif_godina_studija]    Script Date: 01-Dec-25 1:16:31 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[sif_godina_studija](
	[id_godina_studija] [smallint] NOT NULL,
	[akronim] [smallint] NULL,
	[naziv] [nvarchar](50) NULL,
 CONSTRAINT [PK_sif_godina_studija] PRIMARY KEY CLUSTERED 
(
	[id_godina_studija] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[sif_mesto]

-- %%
/****** Object:  Table [dbo].[sif_mesto]    Script Date: 01-Dec-25 1:16:31 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[sif_mesto](
	[id_mesto] [smallint] NOT NULL,
	[naziv] [nvarchar](100) NULL,
 CONSTRAINT [PK_sif_mesto] PRIMARY KEY CLUSTERED 
(
	[id_mesto] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[sif_nacin_upisa]

-- %%
/****** Object:  Table [dbo].[sif_nacin_upisa]    Script Date: 01-Dec-25 1:16:31 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[sif_nacin_upisa](
	[id_nacin_upisa] [smallint] NOT NULL,
	[akronim] [nvarchar](50) NULL,
	[naziv] [nvarchar](100) NULL,
	[f_mirovanje] [bit] NULL,
 CONSTRAINT [PK_sif_nacin_upisa] PRIMARY KEY CLUSTERED 
(
	[id_nacin_upisa] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[sif_opstina]

-- %%
/****** Object:  Table [dbo].[sif_opstina]    Script Date: 01-Dec-25 1:16:31 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[sif_opstina](
	[id_opstina] [smallint] NOT NULL,
	[naziv] [nvarchar](100) NULL,
 CONSTRAINT [PK_sif_opstina] PRIMARY KEY CLUSTERED 
(
	[id_opstina] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[sif_rok]

-- %%
/****** Object:  Table [dbo].[sif_rok]    Script Date: 01-Dec-25 1:16:31 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[sif_rok](
	[id_rok] [int] NOT NULL,
	[naziv] [nvarchar](50) NULL,
	[id_tip_roka] [smallint] NULL,
	[id_skolska_godina] [smallint] NULL,
 CONSTRAINT [PK_sif_rok] PRIMARY KEY CLUSTERED 
(
	[id_rok] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[sif_semestar]

-- %%
/****** Object:  Table [dbo].[sif_semestar]    Script Date: 01-Dec-25 1:16:31 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[sif_semestar](
	[id_semestar] [smallint] NOT NULL,
	[akronim] [smallint] NULL,
	[naziv] [nvarchar](50) NULL,
 CONSTRAINT [PK_sif_semestar] PRIMARY KEY CLUSTERED 
(
	[id_semestar] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[sif_skolska_godina]

-- %%
/****** Object:  Table [dbo].[sif_skolska_godina]    Script Date: 01-Dec-25 1:16:31 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[sif_skolska_godina](
	[id_skolska_godina] [smallint] NOT NULL,
	[akronim] [varchar](7) NULL,
	[naziv] [varchar](50) NULL,
 CONSTRAINT [PK_sif_skolska_godina] PRIMARY KEY CLUSTERED 
(
	[id_skolska_godina] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[sif_srednja_skola]

-- %%
/****** Object:  Table [dbo].[sif_srednja_skola]    Script Date: 01-Dec-25 1:16:31 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[sif_srednja_skola](
	[id_srednja_skola] [smallint] NOT NULL,
	[naziv] [nvarchar](200) NULL,
	[id_mesto] [smallint] NULL,
	[id_opstina] [smallint] NULL,
	[id_drzava] [int] NULL,
 CONSTRAINT [PK_sif_srednja_skola] PRIMARY KEY CLUSTERED 
(
	[id_srednja_skola] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[sif_status_upisa]

-- %%
/****** Object:  Table [dbo].[sif_status_upisa]    Script Date: 01-Dec-25 1:16:31 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[sif_status_upisa](
	[id_status_upisa] [smallint] NOT NULL,
	[akronim] [nvarchar](10) NULL,
	[naziv] [nvarchar](100) NULL,
 CONSTRAINT [PK_sif_status_upisa] PRIMARY KEY CLUSTERED 
(
	[id_status_upisa] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[sif_tip_nastave]

-- %%
/****** Object:  Table [dbo].[sif_tip_nastave]    Script Date: 01-Dec-25 1:16:31 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[sif_tip_nastave](
	[id_tip_nastave] [smallint] NOT NULL,
	[akronim] [nvarchar](10) NULL,
	[naziv] [nvarchar](100) NULL,
 CONSTRAINT [PK_sif_tip_nastave] PRIMARY KEY CLUSTERED 
(
	[id_tip_nastave] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[sif_tip_prijave]

-- %%
/****** Object:  Table [dbo].[sif_tip_prijave]    Script Date: 01-Dec-25 1:16:31 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[sif_tip_prijave](
	[id_tip_prijave] [smallint] NOT NULL,
	[akronim] [nvarchar](10) NULL,
	[naziv] [nvarchar](50) NULL,
 CONSTRAINT [PK_sif_tip_prijave] PRIMARY KEY CLUSTERED 
(
	[id_tip_prijave] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[sif_tip_rezultata_ispita]

-- %%
/****** Object:  Table [dbo].[sif_tip_rezultata_ispita]    Script Date: 01-Dec-25 1:16:31 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[sif_tip_rezultata_ispita](
	[id_tip_rezultata_ispita] [smallint] NOT NULL,
	[akronim] [nvarchar](10) NULL,
	[naziv] [nvarchar](100) NULL,
	[f_polozen] [bit] NULL,
 CONSTRAINT [PK_sif_tip_rezultata_ispita] PRIMARY KEY CLUSTERED 
(
	[id_tip_rezultata_ispita] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[sif_tip_roka]

-- %%
/****** Object:  Table [dbo].[sif_tip_roka]    Script Date: 01-Dec-25 1:16:31 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[sif_tip_roka](
	[id_tip_roka] [smallint] NOT NULL,
	[akronim] [smallint] NULL,
	[naziv] [nvarchar](50) NULL,
 CONSTRAINT [PK_sif_tip_roka] PRIMARY KEY CLUSTERED 
(
	[id_tip_roka] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[sif_tip_studija]

-- %%
/****** Object:  Table [dbo].[sif_tip_studija]    Script Date: 01-Dec-25 1:16:31 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[sif_tip_studija](
	[id_tip_studija] [smallint] NOT NULL,
	[naziv] [nvarchar](50) NULL,
 CONSTRAINT [PK_sif_tip_studija] PRIMARY KEY CLUSTERED 
(
	[id_tip_studija] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[sif_zvanje]

-- %%
/****** Object:  Table [dbo].[sif_zvanje]    Script Date: 01-Dec-25 1:16:31 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[sif_zvanje](
	[id_zvanje] [smallint] NOT NULL,
	[naziv] [nvarchar](50) NULL,
 CONSTRAINT [PK_sif_zvanje] PRIMARY KEY CLUSTERED 
(
	[id_zvanje] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[student]

-- %%
/****** Object:  Table [dbo].[student]    Script Date: 01-Dec-25 1:16:31 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[student](
	[id_student] [smallint] NOT NULL,
	[student_ime] [nvarchar](50) NULL,
	[student_prezime] [nvarchar](50) NULL,
	[id_tip_studija] [smallint] NULL,
	[pol] [smallint] NULL,
	[godina_rodjenja] [smallint] NULL,
	[id_srednja_skola] [smallint] NULL,
	[godina_zavrsetka] [smallint] NULL,
	[id_mesto_rodjenja] [smallint] NULL,
	[id_opstina_rodjenja] [smallint] NULL,
	[id_drzava_rodjenja] [int] NULL,
	[id_mesto_tokom_studija] [smallint] NULL,
	[id_opstina_tokom_studija] [smallint] NULL,
	[id_drzava_tokom_studija] [int] NULL,
	[id_mesto_stanovanja] [smallint] NULL,
	[id_opstina_stanovanja] [smallint] NULL,
	[id_drzava_stanovanja] [int] NULL,
	[prosecna_ocena_1] [real] NULL,
	[prosecna_ocena_2] [real] NULL,
	[prosecna_ocena_3] [real] NULL,
	[prosecna_ocena_4] [real] NULL,
	[uspeh_bodovi] [real] NULL,
	[prijemni_bodovi] [real] NULL,
	[datum_diplomiranja] [varchar](50) NULL,
 CONSTRAINT [PK_student] PRIMARY KEY CLUSTERED 
(
	[id_student] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[upis]

-- %%
/****** Object:  Table [dbo].[upis]    Script Date: 01-Dec-25 1:16:31 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[upis](
	[id_upis] [int] NOT NULL,
	[datum] [varchar](50) NULL,
	[koji_put] [smallint] NULL,
	[id_godina_studija] [smallint] NULL,
	[id_nacin_upisa] [smallint] NULL,
	[id_skolska_godina] [smallint] NULL,
	[id_status_upisa] [smallint] NULL,
	[id_student] [smallint] NULL,
	[vazi_do] [varchar](50) NULL,
	[id_profil] [smallint] NULL,
 CONSTRAINT [PK_upis] PRIMARY KEY CLUSTERED 
(
	[id_upis] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [FK_angazovanje_nastavnik]

-- %%
ALTER TABLE [dbo].[angazovanje]  WITH CHECK ADD  CONSTRAINT [FK_angazovanje_nastavnik] FOREIGN KEY([id_nastavnik])
REFERENCES [dbo].[nastavnik] ([id_nastavnik])
GO
ALTER TABLE [dbo].[angazovanje] CHECK CONSTRAINT [FK_angazovanje_nastavnik]
GO

-- %% [markdown]
-- # [FK_angazovanje_predmet]

-- %%
ALTER TABLE [dbo].[angazovanje]  WITH CHECK ADD  CONSTRAINT [FK_angazovanje_predmet] FOREIGN KEY([id_predmet])
REFERENCES [dbo].[predmet] ([id_predmet])
GO
ALTER TABLE [dbo].[angazovanje] CHECK CONSTRAINT [FK_angazovanje_predmet]
GO

-- %% [markdown]
-- # [FK_angazovanje_sif_tip_nastave]

-- %%
ALTER TABLE [dbo].[angazovanje]  WITH CHECK ADD  CONSTRAINT [FK_angazovanje_sif_tip_nastave] FOREIGN KEY([id_tip_nastave])
REFERENCES [dbo].[sif_tip_nastave] ([id_tip_nastave])
GO
ALTER TABLE [dbo].[angazovanje] CHECK CONSTRAINT [FK_angazovanje_sif_tip_nastave]
GO

-- %% [markdown]
-- # [FK_moguca_prijava_predmet]

-- %%
ALTER TABLE [dbo].[moguca_prijava]  WITH CHECK ADD  CONSTRAINT [FK_moguca_prijava_predmet] FOREIGN KEY([id_predmet])
REFERENCES [dbo].[predmet] ([id_predmet])
GO
ALTER TABLE [dbo].[moguca_prijava] CHECK CONSTRAINT [FK_moguca_prijava_predmet]
GO

-- %% [markdown]
-- # [FK_moguca_prijava_sif_tip_prijave]

-- %%
ALTER TABLE [dbo].[moguca_prijava]  WITH CHECK ADD  CONSTRAINT [FK_moguca_prijava_sif_tip_prijave] FOREIGN KEY([id_tip_prijave])
REFERENCES [dbo].[sif_tip_prijave] ([id_tip_prijave])
GO
ALTER TABLE [dbo].[moguca_prijava] CHECK CONSTRAINT [FK_moguca_prijava_sif_tip_prijave]
GO

-- %% [markdown]
-- # [FK_moguca_prijava_student]

-- %%
ALTER TABLE [dbo].[moguca_prijava]  WITH CHECK ADD  CONSTRAINT [FK_moguca_prijava_student] FOREIGN KEY([id_student])
REFERENCES [dbo].[student] ([id_student])
GO
ALTER TABLE [dbo].[moguca_prijava] CHECK CONSTRAINT [FK_moguca_prijava_student]
GO

-- %% [markdown]
-- # [FK_pracenje_predmeta_predmet]

-- %%
ALTER TABLE [dbo].[pracenje_predmeta]  WITH CHECK ADD  CONSTRAINT [FK_pracenje_predmeta_predmet] FOREIGN KEY([id_predmet])
REFERENCES [dbo].[predmet] ([id_predmet])
GO
ALTER TABLE [dbo].[pracenje_predmeta] CHECK CONSTRAINT [FK_pracenje_predmeta_predmet]
GO

-- %% [markdown]
-- # [FK_pracenje_predmeta_sif_semestar]

-- %%
ALTER TABLE [dbo].[pracenje_predmeta]  WITH CHECK ADD  CONSTRAINT [FK_pracenje_predmeta_sif_semestar] FOREIGN KEY([id_semestar])
REFERENCES [dbo].[sif_semestar] ([id_semestar])
GO
ALTER TABLE [dbo].[pracenje_predmeta] CHECK CONSTRAINT [FK_pracenje_predmeta_sif_semestar]
GO

-- %% [markdown]
-- # [FK_pracenje_predmeta_sif_skolska_godina]

-- %%
ALTER TABLE [dbo].[pracenje_predmeta]  WITH CHECK ADD  CONSTRAINT [FK_pracenje_predmeta_sif_skolska_godina] FOREIGN KEY([id_skolska_godina])
REFERENCES [dbo].[sif_skolska_godina] ([id_skolska_godina])
GO
ALTER TABLE [dbo].[pracenje_predmeta] CHECK CONSTRAINT [FK_pracenje_predmeta_sif_skolska_godina]
GO

-- %% [markdown]
-- # [FK_pracenje_predmeta_sif_tip_prijave]

-- %%
ALTER TABLE [dbo].[pracenje_predmeta]  WITH CHECK ADD  CONSTRAINT [FK_pracenje_predmeta_sif_tip_prijave] FOREIGN KEY([id_tip_prijave])
REFERENCES [dbo].[sif_tip_prijave] ([id_tip_prijave])
GO
ALTER TABLE [dbo].[pracenje_predmeta] CHECK CONSTRAINT [FK_pracenje_predmeta_sif_tip_prijave]
GO

-- %% [markdown]
-- # [FK_pracenje_predmeta_student]

-- %%
ALTER TABLE [dbo].[pracenje_predmeta]  WITH CHECK ADD  CONSTRAINT [FK_pracenje_predmeta_student] FOREIGN KEY([id_student])
REFERENCES [dbo].[student] ([id_student])
GO
ALTER TABLE [dbo].[pracenje_predmeta] CHECK CONSTRAINT [FK_pracenje_predmeta_student]
GO

-- %% [markdown]
-- # [FK_rezultat_ispita_nastavnik]

-- %%
ALTER TABLE [dbo].[rezultat_ispita]  WITH CHECK ADD  CONSTRAINT [FK_rezultat_ispita_nastavnik] FOREIGN KEY([id_nastavnik])
REFERENCES [dbo].[nastavnik] ([id_nastavnik])
GO
ALTER TABLE [dbo].[rezultat_ispita] CHECK CONSTRAINT [FK_rezultat_ispita_nastavnik]
GO

-- %% [markdown]
-- # [FK_rezultat_ispita_predmet]

-- %%
ALTER TABLE [dbo].[rezultat_ispita]  WITH CHECK ADD  CONSTRAINT [FK_rezultat_ispita_predmet] FOREIGN KEY([id_predmet])
REFERENCES [dbo].[predmet] ([id_predmet])
GO
ALTER TABLE [dbo].[rezultat_ispita] CHECK CONSTRAINT [FK_rezultat_ispita_predmet]
GO

-- %% [markdown]
-- # [FK_rezultat_ispita_sif_rok]

-- %%
ALTER TABLE [dbo].[rezultat_ispita]  WITH CHECK ADD  CONSTRAINT [FK_rezultat_ispita_sif_rok] FOREIGN KEY([id_rok])
REFERENCES [dbo].[sif_rok] ([id_rok])
GO
ALTER TABLE [dbo].[rezultat_ispita] CHECK CONSTRAINT [FK_rezultat_ispita_sif_rok]
GO

-- %% [markdown]
-- # [FK_rezultat_ispita_sif_tip_prijave]

-- %%
ALTER TABLE [dbo].[rezultat_ispita]  WITH CHECK ADD  CONSTRAINT [FK_rezultat_ispita_sif_tip_prijave] FOREIGN KEY([id_tip_prijave])
REFERENCES [dbo].[sif_tip_prijave] ([id_tip_prijave])
GO
ALTER TABLE [dbo].[rezultat_ispita] CHECK CONSTRAINT [FK_rezultat_ispita_sif_tip_prijave]
GO

-- %% [markdown]
-- # [FK_rezultat_ispita_sif_tip_rezultata_ispita]

-- %%
ALTER TABLE [dbo].[rezultat_ispita]  WITH CHECK ADD  CONSTRAINT [FK_rezultat_ispita_sif_tip_rezultata_ispita] FOREIGN KEY([id_tip_rezultata_ispita])
REFERENCES [dbo].[sif_tip_rezultata_ispita] ([id_tip_rezultata_ispita])
GO
ALTER TABLE [dbo].[rezultat_ispita] CHECK CONSTRAINT [FK_rezultat_ispita_sif_tip_rezultata_ispita]
GO

-- %% [markdown]
-- # [FK_rezultat_ispita_student]

-- %%
ALTER TABLE [dbo].[rezultat_ispita]  WITH CHECK ADD  CONSTRAINT [FK_rezultat_ispita_student] FOREIGN KEY([id_student])
REFERENCES [dbo].[student] ([id_student])
GO
ALTER TABLE [dbo].[rezultat_ispita] CHECK CONSTRAINT [FK_rezultat_ispita_student]
GO

-- %% [markdown]
-- # [FK_sif_rok_sif_skolska_godina]

-- %%
ALTER TABLE [dbo].[sif_rok]  WITH CHECK ADD  CONSTRAINT [FK_sif_rok_sif_skolska_godina] FOREIGN KEY([id_skolska_godina])
REFERENCES [dbo].[sif_skolska_godina] ([id_skolska_godina])
GO
ALTER TABLE [dbo].[sif_rok] CHECK CONSTRAINT [FK_sif_rok_sif_skolska_godina]
GO

-- %% [markdown]
-- # [FK_sif_rok_sif_tip_roka]

-- %%
ALTER TABLE [dbo].[sif_rok]  WITH CHECK ADD  CONSTRAINT [FK_sif_rok_sif_tip_roka] FOREIGN KEY([id_tip_roka])
REFERENCES [dbo].[sif_tip_roka] ([id_tip_roka])
GO
ALTER TABLE [dbo].[sif_rok] CHECK CONSTRAINT [FK_sif_rok_sif_tip_roka]
GO

-- %% [markdown]
-- # [FK_student_sif_drzava]

-- %%
ALTER TABLE [dbo].[student]  WITH CHECK ADD  CONSTRAINT [FK_student_sif_drzava] FOREIGN KEY([id_drzava_rodjenja])
REFERENCES [dbo].[sif_drzava] ([id_drzava])
GO
ALTER TABLE [dbo].[student] CHECK CONSTRAINT [FK_student_sif_drzava]
GO

-- %% [markdown]
-- # [FK_student_sif_drzava1]

-- %%
ALTER TABLE [dbo].[student]  WITH CHECK ADD  CONSTRAINT [FK_student_sif_drzava1] FOREIGN KEY([id_drzava_tokom_studija])
REFERENCES [dbo].[sif_drzava] ([id_drzava])
GO
ALTER TABLE [dbo].[student] CHECK CONSTRAINT [FK_student_sif_drzava1]
GO

-- %% [markdown]
-- # [FK_student_sif_drzava2]

-- %%
ALTER TABLE [dbo].[student]  WITH CHECK ADD  CONSTRAINT [FK_student_sif_drzava2] FOREIGN KEY([id_drzava_stanovanja])
REFERENCES [dbo].[sif_drzava] ([id_drzava])
GO
ALTER TABLE [dbo].[student] CHECK CONSTRAINT [FK_student_sif_drzava2]
GO

-- %% [markdown]
-- # [FK_student_sif_opstina]

-- %%
ALTER TABLE [dbo].[student]  WITH CHECK ADD  CONSTRAINT [FK_student_sif_opstina] FOREIGN KEY([id_opstina_rodjenja])
REFERENCES [dbo].[sif_opstina] ([id_opstina])
GO
ALTER TABLE [dbo].[student] CHECK CONSTRAINT [FK_student_sif_opstina]
GO

-- %% [markdown]
-- # [FK_student_sif_opstina1]

-- %%
ALTER TABLE [dbo].[student]  WITH CHECK ADD  CONSTRAINT [FK_student_sif_opstina1] FOREIGN KEY([id_opstina_tokom_studija])
REFERENCES [dbo].[sif_opstina] ([id_opstina])
GO
ALTER TABLE [dbo].[student] CHECK CONSTRAINT [FK_student_sif_opstina1]
GO

-- %% [markdown]
-- # [FK_student_sif_opstina2]

-- %%
ALTER TABLE [dbo].[student]  WITH CHECK ADD  CONSTRAINT [FK_student_sif_opstina2] FOREIGN KEY([id_opstina_stanovanja])
REFERENCES [dbo].[sif_opstina] ([id_opstina])
GO
ALTER TABLE [dbo].[student] CHECK CONSTRAINT [FK_student_sif_opstina2]
GO

-- %% [markdown]
-- # [FK_student_sif_tip_studija]

-- %%
ALTER TABLE [dbo].[student]  WITH CHECK ADD  CONSTRAINT [FK_student_sif_tip_studija] FOREIGN KEY([id_tip_studija])
REFERENCES [dbo].[sif_tip_studija] ([id_tip_studija])
GO
ALTER TABLE [dbo].[student] CHECK CONSTRAINT [FK_student_sif_tip_studija]
GO

-- %% [markdown]
-- # [FK_upis_profil]

-- %%
ALTER TABLE [dbo].[upis]  WITH CHECK ADD  CONSTRAINT [FK_upis_profil] FOREIGN KEY([id_profil])
REFERENCES [dbo].[profil] ([id_profil])
GO
ALTER TABLE [dbo].[upis] CHECK CONSTRAINT [FK_upis_profil]
GO

-- %% [markdown]
-- # [FK_upis_sif_godina_studija]

-- %%
ALTER TABLE [dbo].[upis]  WITH CHECK ADD  CONSTRAINT [FK_upis_sif_godina_studija] FOREIGN KEY([id_godina_studija])
REFERENCES [dbo].[sif_godina_studija] ([id_godina_studija])
GO
ALTER TABLE [dbo].[upis] CHECK CONSTRAINT [FK_upis_sif_godina_studija]
GO

-- %% [markdown]
-- # [FK_upis_sif_nacin_upisa]

-- %%
ALTER TABLE [dbo].[upis]  WITH CHECK ADD  CONSTRAINT [FK_upis_sif_nacin_upisa] FOREIGN KEY([id_nacin_upisa])
REFERENCES [dbo].[sif_nacin_upisa] ([id_nacin_upisa])
GO
ALTER TABLE [dbo].[upis] CHECK CONSTRAINT [FK_upis_sif_nacin_upisa]
GO

-- %% [markdown]
-- # [FK_upis_sif_skolska_godina]

-- %%
ALTER TABLE [dbo].[upis]  WITH CHECK ADD  CONSTRAINT [FK_upis_sif_skolska_godina] FOREIGN KEY([id_skolska_godina])
REFERENCES [dbo].[sif_skolska_godina] ([id_skolska_godina])
GO
ALTER TABLE [dbo].[upis] CHECK CONSTRAINT [FK_upis_sif_skolska_godina]
GO

-- %% [markdown]
-- # [FK_upis_sif_status_upisa]

-- %%
ALTER TABLE [dbo].[upis]  WITH CHECK ADD  CONSTRAINT [FK_upis_sif_status_upisa] FOREIGN KEY([id_status_upisa])
REFERENCES [dbo].[sif_status_upisa] ([id_status_upisa])
GO
ALTER TABLE [dbo].[upis] CHECK CONSTRAINT [FK_upis_sif_status_upisa]
GO

-- %% [markdown]
-- # [FK_upis_student]

-- %%
ALTER TABLE [dbo].[upis]  WITH CHECK ADD  CONSTRAINT [FK_upis_student] FOREIGN KEY([id_student])
REFERENCES [dbo].[student] ([id_student])
GO
ALTER TABLE [dbo].[upis] CHECK CONSTRAINT [FK_upis_student]
GO

-- %% [markdown]
-- # [Studenti]

-- %%
USE [master]
GO

-- %%
ALTER DATABASE [Studenti] SET  READ_WRITE 
GO
